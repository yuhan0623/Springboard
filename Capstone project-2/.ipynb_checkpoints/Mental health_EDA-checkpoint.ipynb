# %% [markdown]
# # Mental Health Capstone Project -- Exploratory Data Analysis
# Here I will focus on  the mental and substance use disorders data. This data includes the share of population with different mental health disorders by country around the world. It includes a range of disorders including depression, anxiety, bipolar, eating disorders, schizophrenia, and alcohol and drug use disorders.

# %%
#load python packages
import os
import pandas as pd
import datetime
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
# load the data
xls = pd.ExcelFile('data/mental_health_output_1.xlsx')
xls.sheet_names
# Out:
# ['prevalence-by-mental-and-substa',
#  'depression-by-level-of-educatio',
#  'prevalence-of-depression-by-age',
#  'prevalence-of-depression-males-',
#  'suicide-rates-vs-prevalence-of-',
#  'number-with-depression-by-count']

# %%
df1_types = pd.read_excel(xls, 'prevalence-by-mental-and-substa')

# %%
df1_types.head()
# Out:
#         Entity Code  Year  Schizophrenia (%)  Bipolar disorder (%)  \
# 0  Afghanistan  AFG  1990           0.160560              0.697779
# 1  Afghanistan  AFG  1991           0.160312              0.697961
# 2  Afghanistan  AFG  1992           0.160135              0.698107
# 3  Afghanistan  AFG  1993           0.160037              0.698257
# 4  Afghanistan  AFG  1994           0.160022              0.698469
#
#    Eating disorders (%)  Anxiety disorders (%)  Drug use disorders (%)  \
# 0              0.101855               4.828830                1.677082
# 1              0.099313               4.829740                1.684746
# 2              0.096692               4.831108                1.694334
# 3              0.094336               4.830864                1.705320
# 4              0.092439               4.829423                1.716069
#
#    Depression (%)  Alcohol use disorders (%)
# 0        4.071831                   0.672404
# 1        4.079531                   0.671768
# 2        4.088358                   0.670644
# 3        4.096190                   0.669738
# 4        4.099582                   0.669260

# %%
df1_types.Entity.nunique()
# Out:
# 231

# %%
df1_types.Year.nunique()
# Out:
# 28

# %% [markdown]
# #### Create a column of total mental and substance use disorders

# %%
df1_types_drop = df1_types.drop(columns=['Entity','Code','Year'])
df1_types['Total (%)'] = df1_types_drop.sum(axis=1)
df1_types.head()
# Out:
#         Entity Code  Year  Schizophrenia (%)  Bipolar disorder (%)  \
# 0  Afghanistan  AFG  1990           0.160560              0.697779
# 1  Afghanistan  AFG  1991           0.160312              0.697961
# 2  Afghanistan  AFG  1992           0.160135              0.698107
# 3  Afghanistan  AFG  1993           0.160037              0.698257
# 4  Afghanistan  AFG  1994           0.160022              0.698469
#
#    Eating disorders (%)  Anxiety disorders (%)  Drug use disorders (%)  \
# 0              0.101855               4.828830                1.677082
# 1              0.099313               4.829740                1.684746
# 2              0.096692               4.831108                1.694334
# 3              0.094336               4.830864                1.705320
# 4              0.092439               4.829423                1.716069
#
#    Depression (%)  Alcohol use disorders (%)  Total (%)
# 0        4.071831                   0.672404  12.210341
# 1        4.079531                   0.671768  12.223370
# 2        4.088358                   0.670644  12.239378
# 3        4.096190                   0.669738  12.254742
# 4        4.099582                   0.669260  12.265264

# %% [markdown]
# ## Build data profiles and tables

# %%
df1_types.describe()
# Out:
#               Year  Schizophrenia (%)  Bipolar disorder (%)  \
# count  6468.000000        6468.000000           6468.000000
# mean   2003.500000           0.211644              0.719145
# std       8.078372           0.044253              0.171589
# min    1990.000000           0.146902              0.314535
# 25%    1996.750000           0.181530              0.615532
# 50%    2003.500000           0.199563              0.693134
# 75%    2010.250000           0.236365              0.835063
# max    2017.000000           0.375110              1.206597
#
#        Eating disorders (%)  Anxiety disorders (%)  Drug use disorders (%)  \
# count           6468.000000            6468.000000             6468.000000
# mean               0.239998               3.989921                0.862278
# std                0.158141               1.167526                0.460679
# min                0.073908               2.023393                0.383650
# 25%                0.122387               3.188824                0.535064
# 50%                0.182525               3.554373                0.726430
# 75%                0.292666               4.682163                0.940157
# max                0.943991               8.967330                3.452476
#
#        Depression (%)  Alcohol use disorders (%)    Total (%)
# count     6468.000000                6468.000000  6468.000000
# mean         3.497654                   1.585821    11.106461
# std          0.655859                   0.860283     2.202924
# min          2.139903                   0.446940     7.611511
# 25%          3.005529                   0.993685     9.401339
# 50%          3.499606                   1.479937    10.533968
# 75%          3.912381                   1.867834    12.290250
# max          6.602754                   5.474668    19.002539

# %% [markdown]
# * Here I notice that Anxiesty disorder and Depression present higher value.
# * There is no big difference between mean and medium(50th percentile).
# * There is a large difference between 75th percentile and max values for Drug and Alcohol use disorder.
# * They suggest that Drug and Alcohol use disorder columns exist extreme values in this data set.

# %% [markdown]
# #### Reviewing for Outliers and Anamolies

# %%
df1_types.drop(columns=['Year']).boxplot(grid=False, vert=False,fontsize=15)

# %% [markdown]
# It shows all columns have outliers with more 1.5×IQR above the third quartile.

# %%
df1_types.hist(figsize =(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000023E1EAE1308>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E1E5FC648>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E1E2FB108>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000023E1E6F5E88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E1E754A88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E1E43BFC8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000023E1DBBC488>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E1DB3B208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E1DB3B408>]],
#       dtype=object)

# %% [markdown]
# Bipolar disorder column appears to be normally distributed. And remaining all variables are right skewed.

# %% [markdown]
# ## Explore data relationships

# %%
# Make a pairplot of the data with dropping 'Year' column
sns.pairplot(df1_types)

# %%
plt.figure(figsize=(14,12))
sns.heatmap(df1_types.corr(),linewidths=.1,cmap="YlGnBu", annot=True)
plt.yticks(rotation=0)
# Out:
# (array([0.5, 1.5, 2.5, 3.5, 4.5, 5.5, 6.5, 7.5]),
#  <a list of 8 Text major ticklabel objects>)

# %% [markdown]
# From the pairplot and corrilation matrix we can infer:
# * There is strong positive correlation between:
# <ul>
# <li>Schizophrenia and Eating disorder</li>
# <li>Bipolar and Eating disorders</li>
# <li>Bipolar and Anxiety disorders</li>
# <li>Eating disorders and Anxiety</li>
# <li>Anxiety and Drug use disorder</li>
# </ul>
# * There is negative corrilation between:
# <ul>
# <li>Alcohol use disorder and Schizophrenia</li>
# <li>Alcohol use disorder and Anxiety disorders</li>
# <li>Alcohol use disorder and Drug use disorder</li>
# </ul>

# %%
# There are too many entried for each feature. Let's only foces on each year with the mean value next. 
# Group by 'Year' and take the mean for all contries
df1_types_year = df1_types.groupby(by='Year').mean()

# %%
df1_types_year.head()
# Out:
#       Schizophrenia (%)  Bipolar disorder (%)  Eating disorders (%)  \
# Year
# 1990           0.209548              0.715392              0.221774
# 1991           0.209586              0.715740              0.222076
# 1992           0.209634              0.716091              0.222481
# 1993           0.209690              0.716430              0.223033
# 1994           0.209751              0.716755              0.223710
#
#       Anxiety disorders (%)  Drug use disorders (%)  Depression (%)  \
# Year
# 1990               3.957269                0.808283        3.506288
# 1991               3.960009                0.813466        3.510948
# 1992               3.962778                0.818692        3.515033
# 1993               3.965405                0.823780        3.518531
# 1994               3.967976                0.828389        3.521437
#
#       Alcohol use disorders (%)  Total (%)
# Year
# 1990                   1.546533  10.965087
# 1991                   1.553500  10.985325
# 1992                   1.559927  11.004636
# 1993                   1.565611  11.022481
# 1994                   1.570127  11.038145

# %%
sns.pairplot(df1_types_year)

# %%
df1_types_year.hist(figsize =(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000023E2CDC0408>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E290B3AC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E2CE25D48>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000023E2D66A148>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E2D6A1748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E2D6D6D88>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000023E2D711448>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E2D747A08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E2D747B88>]],
#       dtype=object)

# %%
df1_types_year.plot()

# %%
plt.figure(figsize=(14,12))
sns.heatmap(df1_types_year.corr(),linewidths=.1,cmap="YlGnBu", annot=True)
plt.yticks(rotation=0)
# Out:
# (array([0.5, 1.5, 2.5, 3.5, 4.5, 5.5, 6.5]),
#  <a list of 7 Text major ticklabel objects>)

# %% [markdown]
# Interesting that Depression has strong negative corrilation with all other disorders.

# %%
# Group by with Country
df1_types_country = df1_types.groupby(by='Entity').mean().drop(columns=['Year'])
df1_types_country.head()
# Out:
#                       Schizophrenia (%)  Bipolar disorder (%)  \
# Entity
# Afghanistan                    0.162974              0.702354
# Albania                        0.196544              0.700092
# Algeria                        0.194960              0.809903
# American Samoa                 0.249785              0.467095
# Andean Latin America           0.197425              0.876089
#
#                       Eating disorders (%)  Anxiety disorders (%)  \
# Entity
# Afghanistan                       0.094261               4.848102
# Albania                           0.145230               3.368903
# Algeria                           0.194488               5.011396
# American Samoa                    0.181259               3.293312
# Andean Latin America              0.316283               4.245343
#
#                       Drug use disorders (%)  Depression (%)  \
# Entity
# Afghanistan                         2.120798        4.118622
# Albania                             0.498765        2.190442
# Algeria                             1.540640        3.657743
# American Samoa                      0.759355        2.940850
# Andean Latin America                0.647127        2.626773
#
#                       Alcohol use disorders (%)  Total (%)
# Entity
# Afghanistan                            0.663151  12.710262
# Albania                                1.746757   8.846732
# Algeria                                0.653712  12.062842
# American Samoa                         1.135266   9.026922
# Andean Latin America                   1.646372  10.555414

# %%
df = df1_types_country.sort_values('Total (%)',ascending=False)
df
# Out:
#                 Schizophrenia (%)  Bipolar disorder (%)  Eating disorders (%)  \
# Entity
# Greenland                0.318408              0.592052              0.500551
# New Zealand              0.340113              1.199014              0.643235
# United States            0.338117              0.653710              0.513658
# Australasia              0.360540              1.153425              0.806650
# North America            0.335768              0.659933              0.508377
# ...                           ...                   ...                   ...
# Southeast Asia           0.221765              0.536028              0.121638
# Vietnam                  0.233553              0.545323              0.102642
# Mali                     0.165141              0.625859              0.107096
# Indonesia                0.221483              0.536945              0.124251
# Myanmar                  0.199303              0.504133              0.092004
#
#                 Anxiety disorders (%)  Drug use disorders (%)  Depression (%)  \
# Entity
# Greenland                    5.669651                1.814019        6.459109
# New Zealand                  8.651309                2.116917        4.086397
# United States                6.741584                2.844713        4.744655
# Australasia                  6.895850                2.182412        4.679497
# North America                6.590146                2.777057        4.674825
# ...                               ...                     ...             ...
# Southeast Asia               3.134704                0.620847        2.796893
# Vietnam                      2.035264                0.648821        2.910582
# Mali                         2.878330                0.426686        2.979703
# Indonesia                    3.258047                0.555185        2.623058
# Myanmar                      3.259851                0.564646        2.252113
#
#                 Alcohol use disorders (%)  Total (%)
# Entity
# Greenland                        3.433462  18.787251
# New Zealand                      1.690873  18.727858
# United States                    2.046643  17.883080
# Australasia                      1.522012  17.600386
# North America                    1.998468  17.544574
# ...                                   ...        ...
# Southeast Asia                   0.880189   8.312065
# Vietnam                          1.597560   8.073747
# Mali                             0.890078   8.072895
# Indonesia                        0.600379   7.919348
# Myanmar                          0.854296   7.726345
#
# [231 rows x 8 columns]

# %%
plt.figure(figsize = (10,13))
sns.barplot(x='Total (%)', y=df.index, data=df, color='b')

# %% [markdown]
# The total mental health disorders percentage by country from 18.8 to 7.7. It is vary high portion. Itis clearly that the mental health impacts all over the world and large amount of people.

# %%
df_30 = df.iloc[:30]
plt.figure(figsize = (8,10))
sns.barplot(x='Total (%)', y=df_30.index, data=df_30, color='b')

# %% [markdown]
# From the figure above, The Greenland has highest mental and substance use disorders and US is in the third place with more than 17% percentage to the population. That means around 1 in 6 people has mentel or substance use disorder.

# %% [markdown]
# ### Let's explore suicite rate data to check is there are relationships with these mental and substance use disorders.

# %%
df1_suicide = pd.read_excel(xls, 'suicide-rates-vs-prevalence-of-')

# %%
df1_suicide.head()
# Out:
#         Entity Code  Year  Suicide rate (deaths per 100,000 individuals)  \
# 0  Afghanistan  AFG  1990                                      10.318504
# 1  Afghanistan  AFG  1991                                      10.327010
# 2  Afghanistan  AFG  1992                                      10.271411
# 3  Afghanistan  AFG  1993                                      10.376123
# 4  Afghanistan  AFG  1994                                      10.575915
#
#    Depressive disorder rates (number suffering per 100,000)  Population
# 0                                        4039.755763           12412000
# 1                                        4046.256034           13299000
# 2                                        4053.709902           14486000
# 3                                        4060.203474           15817000
# 4                                        4062.290365           17076000

# %%
df1_suicide.describe()
# Out:
#               Year  Suicide rate (deaths per 100,000 individuals)  \
# count  5488.000000                                    5488.000000
# mean   2003.500000                                      11.953749
# std       8.078483                                       8.361615
# min    1990.000000                                       1.526792
# 25%    1996.750000                                       6.487754
# 50%    2003.500000                                      10.218074
# 75%    2010.250000                                      14.807193
# max    2017.000000                                      98.831696
#
#        Depressive disorder rates (number suffering per 100,000)    Population
# count                                        5488.000000         5.488000e+03
# mean                                         3332.649855         6.556900e+07
# std                                           636.103585         4.755855e+08
# min                                          2065.451870         4.500000e+04
# 25%                                          2840.405347         1.726500e+06
# 50%                                          3326.919130         6.832500e+06
# 75%                                          3719.707955         2.176450e+07
# max                                          6096.437594         7.547859e+09

# %%
# The population will be huge different between countries, so I drop it here for the boxplot.
df1_suicide.drop(columns=['Year', 'Population']).boxplot(grid=False, vert=False,fontsize=15)

# %% [markdown]
# Depression disorder rates and Suicide rate columns all have outliers.

# %% [markdown]
# Combine two datasets

# %%
df1_types_2 = df1_types.set_index(['Entity', 'Code', 'Year'])
df1_suicide_2 = df1_suicide.set_index(['Entity', 'Code','Year'])

# %%
data_frames = [df1_types_2, df1_suicide_2]
df_merged = pd.concat(data_frames, join='outer', axis=1).fillna(np.nan)
df_merged.head()
# Out:
#                        Schizophrenia (%)  Bipolar disorder (%)  \
# Entity      Code Year
# Afghanistan AFG  1990           0.160560              0.697779
#                  1991           0.160312              0.697961
#                  1992           0.160135              0.698107
#                  1993           0.160037              0.698257
#                  1994           0.160022              0.698469
#
#                        Eating disorders (%)  Anxiety disorders (%)  \
# Entity      Code Year
# Afghanistan AFG  1990              0.101855               4.828830
#                  1991              0.099313               4.829740
#                  1992              0.096692               4.831108
#                  1993              0.094336               4.830864
#                  1994              0.092439               4.829423
#
#                        Drug use disorders (%)  Depression (%)  \
# Entity      Code Year
# Afghanistan AFG  1990                1.677082        4.071831
#                  1991                1.684746        4.079531
#                  1992                1.694334        4.088358
#                  1993                1.705320        4.096190
#                  1994                1.716069        4.099582
#
#                        Alcohol use disorders (%)  Total (%)  \
# Entity      Code Year
# Afghanistan AFG  1990                   0.672404  12.210341
#                  1991                   0.671768  12.223370
#                  1992                   0.670644  12.239378
#                  1993                   0.669738  12.254742
#                  1994                   0.669260  12.265264
#
#                        Suicide rate (deaths per 100,000 individuals)  \
# Entity      Code Year
# Afghanistan AFG  1990                                      10.318504
#                  1991                                      10.327010
#                  1992                                      10.271411
#                  1993                                      10.376123
#                  1994                                      10.575915
#
#                        Depressive disorder rates (number suffering per 100,000)  \
# Entity      Code Year
# Afghanistan AFG  1990                                        4039.755763
#                  1991                                        4046.256034
#                  1992                                        4053.709902
#                  1993                                        4060.203474
#                  1994                                        4062.290365
#
#                        Population
# Entity      Code Year
# Afghanistan AFG  1990  12412000.0
#                  1991  13299000.0
#                  1992  14486000.0
#                  1993  15817000.0
#                  1994  17076000.0

# %%
df_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 6468 entries, ('Afghanistan', 'AFG', 1990) to ('Zimbabwe', 'ZWE', 2017)
# Data columns (total 11 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   Schizophrenia (%)                                         6468 non-null   float64
#  1   Bipolar disorder (%)                                      6468 non-null   float64
#  2   Eating disorders (%)                                      6468 non-null   float64
#  3   Anxiety disorders (%)                                     6468 non-null   float64
#  4   Drug use disorders (%)                                    6468 non-null   float64
#  5   Depression (%)                                            6468 non-null   float64
#  6   Alcohol use disorders (%)                                 6468 non-null   float64
#  7   Total (%)                                                 6468 non-null   float64
#  8   Suicide rate (deaths per 100,000 individuals)             5488 non-null   float64
#  9   Depressive disorder rates (number suffering per 100,000)  5488 non-null   float64
#  10  Population                                                5488 non-null   float64
# dtypes: float64(11)
# memory usage: 591.2+ KB

# %%
# check the null rows
df_na = df_merged[df_merged.isna().any(axis=1)]
df_na
# Out:
#                                       Schizophrenia (%)  Bipolar disorder (%)  \
# Entity                     Code Year
# Andean Latin America       NaN  1990           0.195471              0.870564
#                                 1991           0.195484              0.870876
#                                 1992           0.195497              0.871174
#                                 1993           0.195523              0.871482
#                                 1994           0.195569              0.871823
# ...                                                 ...                   ...
# Western Sub-Saharan Africa NaN  2013           0.173905              0.635737
#                                 2014           0.174254              0.636185
#                                 2015           0.174616              0.636682
#                                 2016           0.174980              0.637211
#                                 2017           0.175340              0.637776
#
#                                       Eating disorders (%)  \
# Entity                     Code Year
# Andean Latin America       NaN  1990              0.287820
#                                 1991              0.289362
#                                 1992              0.290563
#                                 1993              0.291833
#                                 1994              0.293111
# ...                                                    ...
# Western Sub-Saharan Africa NaN  2013              0.136469
#                                 2014              0.138116
#                                 2015              0.139784
#                                 2016              0.141193
#                                 2017              0.142431
#
#                                       Anxiety disorders (%)  \
# Entity                     Code Year
# Andean Latin America       NaN  1990               4.217677
#                                 1991               4.220261
#                                 1992               4.222587
#                                 1993               4.224721
#                                 1994               4.226690
# ...                                                     ...
# Western Sub-Saharan Africa NaN  2013               2.899641
#                                 2014               2.902038
#                                 2015               2.904311
#                                 2016               2.906350
#                                 2017               2.908183
#
#                                       Drug use disorders (%)  Depression (%)  \
# Entity                     Code Year
# Andean Latin America       NaN  1990                0.608921        2.621781
#                                 1991                0.610489        2.631717
#                                 1992                0.611990        2.639932
#                                 1993                0.613995        2.646096
#                                 1994                0.616448        2.651022
# ...                                                      ...             ...
# Western Sub-Saharan Africa NaN  2013                0.477964        3.805780
#                                 2014                0.480415        3.787750
#                                 2015                0.482921        3.762850
#                                 2016                0.485547        3.733871
#                                 2017                0.488562        3.699654
#
#                                       Alcohol use disorders (%)  Total (%)  \
# Entity                     Code Year
# Andean Latin America       NaN  1990                   1.748912  10.551145
#                                 1991                   1.743910  10.562099
#                                 1992                   1.738703  10.570446
#                                 1993                   1.733697  10.577347
#                                 1994                   1.729266  10.583929
# ...                                                         ...        ...
# Western Sub-Saharan Africa NaN  2013                   0.966526   9.096023
#                                 2014                   0.967383   9.086141
#                                 2015                   0.968057   9.069222
#                                 2016                   0.968472   9.047623
#                                 2017                   0.968598   9.020543
#
#                                       Suicide rate (deaths per 100,000 individuals)  \
# Entity                     Code Year
# Andean Latin America       NaN  1990                                            NaN
#                                 1991                                            NaN
#                                 1992                                            NaN
#                                 1993                                            NaN
#                                 1994                                            NaN
# ...                                                                             ...
# Western Sub-Saharan Africa NaN  2013                                            NaN
#                                 2014                                            NaN
#                                 2015                                            NaN
#                                 2016                                            NaN
#                                 2017                                            NaN
#
#                                       Depressive disorder rates (number suffering per 100,000)  \
# Entity                     Code Year
# Andean Latin America       NaN  1990                                                NaN
#                                 1991                                                NaN
#                                 1992                                                NaN
#                                 1993                                                NaN
#                                 1994                                                NaN
# ...                                                                                 ...
# Western Sub-Saharan Africa NaN  2013                                                NaN
#                                 2014                                                NaN
#                                 2015                                                NaN
#                                 2016                                                NaN
#                                 2017                                                NaN
#
#                                       Population
# Entity                     Code Year
# Andean Latin America       NaN  1990         NaN
#                                 1991         NaN
#                                 1992         NaN
#                                 1993         NaN
#                                 1994         NaN
# ...                                          ...
# Western Sub-Saharan Africa NaN  2013         NaN
#                                 2014         NaN
#                                 2015         NaN
#                                 2016         NaN
#                                 2017         NaN
#
# [980 rows x 11 columns]

# %%
# I was going to check the unique entity in null values data, but this method seems not working well
df_na.index.levels[0]
# Out:
# Index(['Afghanistan', 'Albania', 'Algeria', 'American Samoa',
#        'Andean Latin America', 'Andorra', 'Angola', 'Antigua and Barbuda',
#        'Argentina', 'Armenia',
#        ...
#        'Vanuatu', 'Venezuela', 'Vietnam', 'Wales', 'Western Europe',
#        'Western Sub-Saharan Africa', 'World', 'Yemen', 'Zambia', 'Zimbabwe'],
#       dtype='object', name='Entity', length=231)

# %%
# Check the unique value of entity
df_na_1 = df_na.reset_index()
df_na_1.Entity.unique()
# Out:
# array(['Andean Latin America', 'Australasia', 'Caribbean', 'Central Asia',
#        'Central Europe',
#        'Central Europe, Eastern Europe, and Central Asia',
#        'Central Latin America', 'Central Sub-Saharan Africa', 'East Asia',
#        'Eastern Europe', 'Eastern Sub-Saharan Africa', 'England',
#        'High SDI', 'High-income', 'High-income Asia Pacific',
#        'High-middle SDI', 'Latin America and Caribbean', 'Low SDI',
#        'Low-middle SDI', 'Middle SDI', 'North Africa and Middle East',
#        'North America', 'Northern Ireland', 'Oceania', 'Scotland',
#        'South Asia', 'Southeast Asia',
#        'Southeast Asia, East Asia, and Oceania', 'Southern Latin America',
#        'Southern Sub-Saharan Africa', 'Sub-Saharan Africa',
#        'Tropical Latin America', 'Wales', 'Western Europe',
#        'Western Sub-Saharan Africa'], dtype=object)

# %% [markdown]
# It looks like most Entities in the null data are region, not coutry. We can drop those data.

# %%
df_merged.dropna(inplace=True)
df_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 5488 entries, ('Afghanistan', 'AFG', 1990) to ('Zimbabwe', 'ZWE', 2017)
# Data columns (total 11 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   Schizophrenia (%)                                         5488 non-null   float64
#  1   Bipolar disorder (%)                                      5488 non-null   float64
#  2   Eating disorders (%)                                      5488 non-null   float64
#  3   Anxiety disorders (%)                                     5488 non-null   float64
#  4   Drug use disorders (%)                                    5488 non-null   float64
#  5   Depression (%)                                            5488 non-null   float64
#  6   Alcohol use disorders (%)                                 5488 non-null   float64
#  7   Total (%)                                                 5488 non-null   float64
#  8   Suicide rate (deaths per 100,000 individuals)             5488 non-null   float64
#  9   Depressive disorder rates (number suffering per 100,000)  5488 non-null   float64
#  10  Population                                                5488 non-null   float64
# dtypes: float64(11)
# memory usage: 502.2+ KB

# %%
sns.pairplot(df_merged)

# %%
plt.figure(figsize=(14,12))
sns.heatmap(df_merged.corr(),linewidths=.1,cmap="YlGnBu", annot=True)
plt.yticks(rotation=0)
# Out:
# (array([ 0.5,  1.5,  2.5,  3.5,  4.5,  5.5,  6.5,  7.5,  8.5,  9.5, 10.5]),
#  <a list of 11 Text major ticklabel objects>)

# %% [markdown]
# The suicide rate shows positive corrilation with Depression and Alcohol use disorders. Let's take a closer look at the relationships between them.

# %%
# Plot the relationship between suicide rate and Depression
sns.jointplot(x='Depression (%)', y='Suicide rate (deaths per 100,000 individuals)', data=df_merged, kind="reg")

# %%
# plot the realationship between suicide rate and Alcocol
sns.jointplot(x='Alcohol use disorders (%)', y='Suicide rate (deaths per 100,000 individuals)', data=df_merged, kind="reg")

# %% [markdown]
# ### Remove the ouliers to check the relationship again.

# %%
# drop the outliers
Q1 = df1_suicide.quantile(0.25)
 
Q3 = df1_suicide.quantile(0.75)

IQR = Q3 - Q1
# Not outliers
df1_suicide_no = df1_suicide[~((df1_suicide < (Q1 - 1.5 * IQR)) |(df1_suicide > (Q3 + 1.5 * IQR))).any(axis=1)]
df1_suicide_no.head()
# Out:
#         Entity Code  Year  Suicide rate (deaths per 100,000 individuals)  \
# 0  Afghanistan  AFG  1990                                      10.318504
# 1  Afghanistan  AFG  1991                                      10.327010
# 2  Afghanistan  AFG  1992                                      10.271411
# 3  Afghanistan  AFG  1993                                      10.376123
# 4  Afghanistan  AFG  1994                                      10.575915
#
#    Depressive disorder rates (number suffering per 100,000)  Population
# 0                                        4039.755763           12412000
# 1                                        4046.256034           13299000
# 2                                        4053.709902           14486000
# 3                                        4060.203474           15817000
# 4                                        4062.290365           17076000

# %%
df1_suicide_no[['Suicide rate (deaths per 100,000 individuals)']].boxplot(grid=False, fontsize=15)

# %%
df1_types_3 = df1_types.set_index(['Entity', 'Code', 'Year'])
df1_suicide_3 = df1_suicide_no.set_index(['Entity', 'Code','Year'])

# %%
data_frames_2 = [df1_types_3, df1_suicide_3]
df_merged_2 = pd.concat(data_frames_2, join='outer', axis=1).fillna(np.nan)
df_merged_2.head()
# Out:
#                        Schizophrenia (%)  Bipolar disorder (%)  \
# Entity      Code Year
# Afghanistan AFG  1990           0.160560              0.697779
#                  1991           0.160312              0.697961
#                  1992           0.160135              0.698107
#                  1993           0.160037              0.698257
#                  1994           0.160022              0.698469
#
#                        Eating disorders (%)  Anxiety disorders (%)  \
# Entity      Code Year
# Afghanistan AFG  1990              0.101855               4.828830
#                  1991              0.099313               4.829740
#                  1992              0.096692               4.831108
#                  1993              0.094336               4.830864
#                  1994              0.092439               4.829423
#
#                        Drug use disorders (%)  Depression (%)  \
# Entity      Code Year
# Afghanistan AFG  1990                1.677082        4.071831
#                  1991                1.684746        4.079531
#                  1992                1.694334        4.088358
#                  1993                1.705320        4.096190
#                  1994                1.716069        4.099582
#
#                        Alcohol use disorders (%)  \
# Entity      Code Year
# Afghanistan AFG  1990                   0.672404
#                  1991                   0.671768
#                  1992                   0.670644
#                  1993                   0.669738
#                  1994                   0.669260
#
#                        Suicide rate (deaths per 100,000 individuals)  \
# Entity      Code Year
# Afghanistan AFG  1990                                      10.318504
#                  1991                                      10.327010
#                  1992                                      10.271411
#                  1993                                      10.376123
#                  1994                                      10.575915
#
#                        Depressive disorder rates (number suffering per 100,000)  \
# Entity      Code Year
# Afghanistan AFG  1990                                        4039.755763
#                  1991                                        4046.256034
#                  1992                                        4053.709902
#                  1993                                        4060.203474
#                  1994                                        4062.290365
#
#                        Population
# Entity      Code Year
# Afghanistan AFG  1990  12412000.0
#                  1991  13299000.0
#                  1992  14486000.0
#                  1993  15817000.0
#                  1994  17076000.0

# %%
df_merged_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 6468 entries, ('Afghanistan', 'AFG', 1990) to ('Zimbabwe', 'ZWE', 2017)
# Data columns (total 10 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   Schizophrenia (%)                                         6468 non-null   float64
#  1   Bipolar disorder (%)                                      6468 non-null   float64
#  2   Eating disorders (%)                                      6468 non-null   float64
#  3   Anxiety disorders (%)                                     6468 non-null   float64
#  4   Drug use disorders (%)                                    6468 non-null   float64
#  5   Depression (%)                                            6468 non-null   float64
#  6   Alcohol use disorders (%)                                 6468 non-null   float64
#  7   Suicide rate (deaths per 100,000 individuals)             4536 non-null   float64
#  8   Depressive disorder rates (number suffering per 100,000)  4536 non-null   float64
#  9   Population                                                4536 non-null   float64
# dtypes: float64(10)
# memory usage: 540.6+ KB

# %%
df_merged_2.dropna(inplace=True)
df_merged_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 4536 entries, ('Afghanistan', 'AFG', 1990) to ('Zimbabwe', 'ZWE', 2017)
# Data columns (total 10 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   Schizophrenia (%)                                         4536 non-null   float64
#  1   Bipolar disorder (%)                                      4536 non-null   float64
#  2   Eating disorders (%)                                      4536 non-null   float64
#  3   Anxiety disorders (%)                                     4536 non-null   float64
#  4   Drug use disorders (%)                                    4536 non-null   float64
#  5   Depression (%)                                            4536 non-null   float64
#  6   Alcohol use disorders (%)                                 4536 non-null   float64
#  7   Suicide rate (deaths per 100,000 individuals)             4536 non-null   float64
#  8   Depressive disorder rates (number suffering per 100,000)  4536 non-null   float64
#  9   Population                                                4536 non-null   float64
# dtypes: float64(10)
# memory usage: 380.3+ KB

# %%
sns.pairplot(df_merged_2)

# %%
plt.figure(figsize=(14,12))
sns.heatmap(df_merged_2.corr(),linewidths=.1,cmap="YlGnBu", annot=True)
plt.yticks(rotation=0)
# Out:
# (array([0.5, 1.5, 2.5, 3.5, 4.5, 5.5, 6.5, 7.5, 8.5, 9.5]),
#  <a list of 10 Text major ticklabel objects>)

# %%
# Plot the relationship between suicide rate and Depression
sns.jointplot(x='Depression (%)', y='Suicide rate (deaths per 100,000 individuals)', data=df_merged_2, kind="reg")

# %%
# plot the realationship between suicide rate and Alcocol
sns.jointplot(x='Alcohol use disorders (%)', y='Suicide rate (deaths per 100,000 individuals)', data=df_merged_2, kind="reg")

# %% [markdown]
# After removing the outliers from suicide data, the corrilation between suicide rate and Depression and between suicide rate Alcohol use disorders lower. From the figurs above we can infer that there is no linear relationship between suicide rate and Depression and between suicide rate Alcohol use disorders.

# %% [markdown]
# ## Next, I will explore the age, gender unemployment and gdp datasets.
